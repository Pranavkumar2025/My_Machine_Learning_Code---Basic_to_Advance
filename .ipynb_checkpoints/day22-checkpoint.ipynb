# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# !pip install pandas-profiling
# Out:
# Collecting pandas-profiling
#   Downloading pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
#      ---------------------------------------- 0.0/262.6 kB ? eta -:--:--
#      - -------------------------------------- 10.2/262.6 kB ? eta -:--:--
#      ----- ------------------------------- 41.0/262.6 kB 393.8 kB/s eta 0:00:01
#      -------- ---------------------------- 61.4/262.6 kB 469.7 kB/s eta 0:00:01
#      --------------------- -------------- 153.6/262.6 kB 919.0 kB/s eta 0:00:01
#      --------------------- -------------- 153.6/262.6 kB 919.0 kB/s eta 0:00:01
#      ------------------------------------ 262.6/262.6 kB 952.2 kB/s eta 0:00:00
# Collecting joblib~=1.1.0 (from pandas-profiling)
#   Downloading joblib-1.1.1-py2.py3-none-any.whl (309 kB)
#      ---------------------------------------- 0.0/309.8 kB ? eta -:--:--
#      --------- ------------------------------ 71.7/309.8 kB ? eta -:--:--
#      --------- ------------------------------ 71.7/309.8 kB ? eta -:--:--
#      --------------------------------- ---- 276.5/309.8 kB 1.9 MB/s eta 0:00:01
#      -------------------------------------- 309.8/309.8 kB 1.7 MB/s eta 0:00:00
# Collecting scipy>=1.4.1 (from pandas-profiling)
#   Downloading scipy-1.11.3-cp312-cp312-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      ---------------------------------------- 60.4/60.4 kB 3.1 MB/s eta 0:00:00
# Collecting pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 (from pandas-profiling)
#   Downloading pandas-2.1.2-cp312-cp312-win_amd64.whl.metadata (18 kB)
# Collecting matplotlib>=3.2.0 (from pandas-profiling)
#   Downloading matplotlib-3.8.1-cp312-cp312-win_amd64.whl.metadata (5.9 kB)
# Collecting pydantic>=1.8.1 (from pandas-profiling)
#   Using cached pydantic-2.4.2-py3-none-any.whl.metadata (158 kB)
# Collecting PyYAML>=5.0.0 (from pandas-profiling)
#   Downloading PyYAML-6.0.1-cp312-cp312-win_amd64.whl.metadata (2.1 kB)
# Collecting jinja2>=2.11.1 (from pandas-profiling)
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      ---------------------------------------- 0.0/133.1 kB ? eta -:--:--
#      --------------------- ------------------ 71.7/133.1 kB ? eta -:--:--
#      --------------------- ------------------ 71.7/133.1 kB ? eta -:--:--
#      -------------------------------------- 133.1/133.1 kB 1.1 MB/s eta 0:00:00
# Collecting markupsafe~=2.1.1 (from pandas-profiling)
#   Downloading MarkupSafe-2.1.3-cp312-cp312-win_amd64.whl.metadata (3.0 kB)
# Collecting visions==0.7.4 (from visions[type_image_path]==0.7.4->pandas-profiling)
#   Downloading visions-0.7.4-py3-none-any.whl (102 kB)
#      ---------------------------------------- 0.0/102.4 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/102.4 kB ? eta -:--:--
#      --------------------------------- --- 92.2/102.4 kB 871.5 kB/s eta 0:00:01
#      ------------------------------------ 102.4/102.4 kB 845.4 kB/s eta 0:00:00
# Collecting numpy>=1.16.0 (from pandas-profiling)
#   Downloading numpy-1.26.1-cp312-cp312-win_amd64.whl.metadata (61 kB)
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      ---------------------------------------- 61.2/61.2 kB 1.6 MB/s eta 0:00:00
# Collecting htmlmin>=0.1.12 (from pandas-profiling)
#   Using cached htmlmin-0.1.12.tar.gz (19 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting missingno>=0.4.2 (from pandas-profiling)
#   Using cached missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Collecting phik>=0.11.1 (from pandas-profiling)
#   Downloading phik-0.12.3.tar.gz (620 kB)
#      ---------------------------------------- 0.0/620.3 kB ? eta -:--:--
#       --------------------------------------- 10.2/620.3 kB ? eta -:--:--
#      ----- --------------------------------- 92.2/620.3 kB 1.1 MB/s eta 0:00:01
#      -------- ----------------------------- 143.4/620.3 kB 1.4 MB/s eta 0:00:01
#      ------------ ------------------------- 204.8/620.3 kB 1.2 MB/s eta 0:00:01
#      ---------------- --------------------- 276.5/620.3 kB 1.3 MB/s eta 0:00:01
#      -------------------- ----------------- 337.9/620.3 kB 1.3 MB/s eta 0:00:01
#      ------------------------- ------------ 409.6/620.3 kB 1.3 MB/s eta 0:00:01
#      ---------------------------- --------- 471.0/620.3 kB 1.3 MB/s eta 0:00:01
#      ------------------------------- ------ 522.2/620.3 kB 1.3 MB/s eta 0:00:01
#      ------------------------------- ------ 522.2/620.3 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------  614.4/620.3 kB 1.2 MB/s eta 0:00:01
#      -------------------------------------- 620.3/620.3 kB 1.2 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting tangled-up-in-unicode==0.2.0 (from pandas-profiling)
#   Using cached tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
# Collecting requests>=2.24.0 (from pandas-profiling)
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting tqdm>=4.48.2 (from pandas-profiling)
#   Using cached tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
# Collecting seaborn>=0.10.1 (from pandas-profiling)
#   Downloading seaborn-0.13.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting multimethod>=1.4 (from pandas-profiling)
#   Using cached multimethod-1.10-py3-none-any.whl.metadata (8.2 kB)
# Collecting attrs>=19.3.0 (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling)
#   Downloading attrs-23.1.0-py3-none-any.whl (61 kB)
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      ---------------------------------------- 61.2/61.2 kB ? eta 0:00:00
# Collecting networkx>=2.4 (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling)
#   Using cached networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting imagehash (from visions[type_image_path]==0.7.4->pandas-profiling)
#   Using cached ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
# Collecting Pillow (from visions[type_image_path]==0.7.4->pandas-profiling)
#   Downloading Pillow-10.1.0-cp312-cp312-win_amd64.whl.metadata (9.6 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.2.0->pandas-profiling)
#   Downloading contourpy-1.1.1-cp312-cp312-win_amd64.whl.metadata (5.9 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.2.0->pandas-profiling)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.2.0->pandas-profiling)
#   Downloading fonttools-4.43.1-cp312-cp312-win_amd64.whl.metadata (155 kB)
#      ---------------------------------------- 0.0/155.5 kB ? eta -:--:--
#      ------- -------------------------------- 30.7/155.5 kB ? eta -:--:--
#      --------------------------- ---------- 112.6/155.5 kB 1.6 MB/s eta 0:00:01
#      -------------------------------------- 155.5/155.5 kB 1.3 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.2.0->pandas-profiling)
#   Downloading kiwisolver-1.4.5-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# Collecting packaging>=20.0 (from matplotlib>=3.2.0->pandas-profiling)
#   Using cached packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.2.0->pandas-profiling)
#   Downloading pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting python-dateutil>=2.7 (from matplotlib>=3.2.0->pandas-profiling)
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#      ---------------------------------------- 0.0/247.7 kB ? eta -:--:--
#      -------------- ------------------------ 92.2/247.7 kB 2.6 MB/s eta 0:00:01
#      ------------------ ------------------- 122.9/247.7 kB 2.4 MB/s eta 0:00:01
#      ------------------------------- ------ 204.8/247.7 kB 2.1 MB/s eta 0:00:01
#      -------------------------------------- 247.7/247.7 kB 1.7 MB/s eta 0:00:00
# Collecting pytz>=2020.1 (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling)
#   Downloading pytz-2023.3.post1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.1 (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling)
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ---------------------------------------- 0.0/341.8 kB ? eta -:--:--
#      ------------- ------------------------ 122.9/341.8 kB 2.4 MB/s eta 0:00:01
#      ------------- ------------------------ 122.9/341.8 kB 2.4 MB/s eta 0:00:01
#      -------------------------- ----------- 235.5/341.8 kB 1.8 MB/s eta 0:00:01
#      ------------------------------ ------- 276.5/341.8 kB 1.9 MB/s eta 0:00:01
#      -------------------------------------- 341.8/341.8 kB 1.6 MB/s eta 0:00:00
# Collecting annotated-types>=0.4.0 (from pydantic>=1.8.1->pandas-profiling)
#   Using cached annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.10.1 (from pydantic>=1.8.1->pandas-profiling)
#   Downloading pydantic_core-2.10.1-cp312-none-win_amd64.whl.metadata (6.6 kB)
# Collecting typing-extensions>=4.6.1 (from pydantic>=1.8.1->pandas-profiling)
#   Using cached typing_extensions-4.8.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.24.0->pandas-profiling)
#   Downloading charset_normalizer-3.3.1-cp312-cp312-win_amd64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests>=2.24.0->pandas-profiling)
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
#      ---------------------------------------- 0.0/61.5 kB ? eta -:--:--
#      ---------------------------------------- 61.5/61.5 kB ? eta 0:00:00
# Collecting urllib3<3,>=1.21.1 (from requests>=2.24.0->pandas-profiling)
#   Using cached urllib3-2.0.7-py3-none-any.whl.metadata (6.6 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.24.0->pandas-profiling)
#   Using cached certifi-2023.7.22-py3-none-any.whl.metadata (2.2 kB)
# Collecting colorama (from tqdm>=4.48.2->pandas-profiling)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling)
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting PyWavelets (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling)
#   Downloading PyWavelets-1.4.1.tar.gz (4.6 MB)
#      ---------------------------------------- 0.0/4.6 MB ? eta -:--:--
#      ---------------------------------------- 0.0/4.6 MB 1.9 MB/s eta 0:00:03
#      - -------------------------------------- 0.1/4.6 MB 1.4 MB/s eta 0:00:04
#      - -------------------------------------- 0.2/4.6 MB 1.5 MB/s eta 0:00:03
#      -- ------------------------------------- 0.3/4.6 MB 1.5 MB/s eta 0:00:03
#      -- ------------------------------------- 0.3/4.6 MB 1.4 MB/s eta 0:00:04
#      --- ------------------------------------ 0.4/4.6 MB 1.4 MB/s eta 0:00:04
#      ---- ----------------------------------- 0.5/4.6 MB 1.4 MB/s eta 0:00:03
#      ---- ----------------------------------- 0.5/4.6 MB 1.4 MB/s eta 0:00:03
#      ----- ---------------------------------- 0.6/4.6 MB 1.4 MB/s eta 0:00:03
#      ----- ---------------------------------- 0.6/4.6 MB 1.4 MB/s eta 0:00:03
#      ------ --------------------------------- 0.7/4.6 MB 1.4 MB/s eta 0:00:03
#      ------ --------------------------------- 0.7/4.6 MB 1.4 MB/s eta 0:00:03
#      ------- -------------------------------- 0.8/4.6 MB 1.5 MB/s eta 0:00:03
#      ------- -------------------------------- 0.9/4.6 MB 1.4 MB/s eta 0:00:03
#      -------- ------------------------------- 1.0/4.6 MB 1.4 MB/s eta 0:00:03
#      --------- ------------------------------ 1.1/4.6 MB 1.4 MB/s eta 0:00:03
#      --------- ------------------------------ 1.1/4.6 MB 1.4 MB/s eta 0:00:03
#      ---------- ----------------------------- 1.2/4.6 MB 1.4 MB/s eta 0:00:03
#      ---------- ----------------------------- 1.2/4.6 MB 1.4 MB/s eta 0:00:03
#      ----------- ---------------------------- 1.3/4.6 MB 1.4 MB/s eta 0:00:03
#      ----------- ---------------------------- 1.4/4.6 MB 1.4 MB/s eta 0:00:03
#      ------------ --------------------------- 1.5/4.6 MB 1.4 MB/s eta 0:00:03
#      ------------- -------------------------- 1.5/4.6 MB 1.4 MB/s eta 0:00:03
#      ------------- -------------------------- 1.6/4.6 MB 1.4 MB/s eta 0:00:03
#      -------------- ------------------------- 1.6/4.6 MB 1.4 MB/s eta 0:00:03
#      --------------- ------------------------ 1.7/4.6 MB 1.4 MB/s eta 0:00:02
#      --------------- ------------------------ 1.8/4.6 MB 1.4 MB/s eta 0:00:02
#      ---------------- ----------------------- 1.9/4.6 MB 1.4 MB/s eta 0:00:02
#      ----------------- ---------------------- 2.0/4.6 MB 1.4 MB/s eta 0:00:02
#      ----------------- ---------------------- 2.0/4.6 MB 1.4 MB/s eta 0:00:02
#      ------------------ --------------------- 2.1/4.6 MB 1.4 MB/s eta 0:00:02
#      ------------------ --------------------- 2.1/4.6 MB 1.4 MB/s eta 0:00:02
#      ------------------- -------------------- 2.2/4.6 MB 1.4 MB/s eta 0:00:02
#      ------------------- -------------------- 2.3/4.6 MB 1.4 MB/s eta 0:00:02
#      -------------------- ------------------- 2.4/4.6 MB 1.5 MB/s eta 0:00:02
#      --------------------- ------------------ 2.4/4.6 MB 1.5 MB/s eta 0:00:02
#      --------------------- ------------------ 2.5/4.6 MB 1.4 MB/s eta 0:00:02
#      ---------------------- ----------------- 2.6/4.6 MB 1.4 MB/s eta 0:00:02
#      ----------------------- ---------------- 2.7/4.6 MB 1.5 MB/s eta 0:00:02
#      ----------------------- ---------------- 2.7/4.6 MB 1.5 MB/s eta 0:00:02
#      ------------------------ --------------- 2.8/4.6 MB 1.4 MB/s eta 0:00:02
#      ------------------------ --------------- 2.8/4.6 MB 1.4 MB/s eta 0:00:02
#      ------------------------ --------------- 2.9/4.6 MB 1.5 MB/s eta 0:00:02
#      ------------------------- -------------- 2.9/4.6 MB 1.4 MB/s eta 0:00:02
#      ------------------------- -------------- 3.0/4.6 MB 1.4 MB/s eta 0:00:02
#      -------------------------- ------------- 3.1/4.6 MB 1.4 MB/s eta 0:00:02
#      --------------------------- ------------ 3.1/4.6 MB 1.4 MB/s eta 0:00:02
#      --------------------------- ------------ 3.2/4.6 MB 1.4 MB/s eta 0:00:01
#      ---------------------------- ----------- 3.2/4.6 MB 1.4 MB/s eta 0:00:01
#      ---------------------------- ----------- 3.3/4.6 MB 1.4 MB/s eta 0:00:01
#      ----------------------------- ---------- 3.4/4.6 MB 1.4 MB/s eta 0:00:01
#      ------------------------------ --------- 3.5/4.6 MB 1.4 MB/s eta 0:00:01
#      ------------------------------ --------- 3.5/4.6 MB 1.4 MB/s eta 0:00:01
#      ------------------------------ --------- 3.5/4.6 MB 1.4 MB/s eta 0:00:01
#      ------------------------------- -------- 3.6/4.6 MB 1.4 MB/s eta 0:00:01
#      ------------------------------- -------- 3.6/4.6 MB 1.4 MB/s eta 0:00:01
#      -------------------------------- ------- 3.7/4.6 MB 1.4 MB/s eta 0:00:01
#      --------------------------------- ------ 3.8/4.6 MB 1.4 MB/s eta 0:00:01
#      --------------------------------- ------ 3.9/4.6 MB 1.4 MB/s eta 0:00:01
#      ---------------------------------- ----- 3.9/4.6 MB 1.4 MB/s eta 0:00:01
#      ----------------------------------- ---- 4.0/4.6 MB 1.4 MB/s eta 0:00:01
#      ----------------------------------- ---- 4.1/4.6 MB 1.4 MB/s eta 0:00:01
#      ------------------------------------ --- 4.2/4.6 MB 1.4 MB/s eta 0:00:01
#      ------------------------------------ --- 4.2/4.6 MB 1.4 MB/s eta 0:00:01
#      ------------------------------------ --- 4.2/4.6 MB 1.4 MB/s eta 0:00:01
#      -------------------------------------- - 4.4/4.6 MB 1.4 MB/s eta 0:00:01
#      -------------------------------------- - 4.4/4.6 MB 1.4 MB/s eta 0:00:01
#      -------------------------------------- - 4.5/4.6 MB 1.4 MB/s eta 0:00:01
#      ---------------------------------------  4.5/4.6 MB 1.4 MB/s eta 0:00:01
#      ---------------------------------------  4.6/4.6 MB 1.4 MB/s eta 0:00:01
#      ---------------------------------------- 4.6/4.6 MB 1.4 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   Getting requirements to build wheel did not run successfully.
#   exit code: 1
#
#   [33 lines of output]
#   Traceback (most recent call last):
#     File "C:\Users\Pranav kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 353, in <module>
#       main()
#     File "C:\Users\Pranav kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 335, in main
#       json_out['return_val'] = hook(**hook_input['kwargs'])
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\Pranav kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 112, in get_requires_for_build_wheel
#       backend = _build_backend()
#                 ^^^^^^^^^^^^^^^^
#     File "C:\Users\Pranav kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 77, in _build_backend
#       obj = import_module(mod_path)
#             ^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\Pranav kumar\AppData\Local\Programs\Python\Python312\Lib\importlib\__init__.py", line 90, in import_module
#       return _bootstrap._gcd_import(name[level:], package, level)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "<frozen importlib._bootstrap>", line 1381, in _gcd_import
#     File "<frozen importlib._bootstrap>", line 1354, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 1304, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#     File "<frozen importlib._bootstrap>", line 1381, in _gcd_import
#     File "<frozen importlib._bootstrap>", line 1354, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 1325, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 929, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 994, in exec_module
#     File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#     File "C:\Users\Pranav kumar\AppData\Local\Temp\pip-build-env-ae81z2p5\overlay\Lib\site-packages\setuptools\__init__.py", line 16, in <module>
#       import setuptools.version
#     File "C:\Users\Pranav kumar\AppData\Local\Temp\pip-build-env-ae81z2p5\overlay\Lib\site-packages\setuptools\version.py", line 1, in <module>
#       import pkg_resources
#     File "C:\Users\Pranav kumar\AppData\Local\Temp\pip-build-env-ae81z2p5\overlay\Lib\site-packages\pkg_resources\__init__.py", line 2191, in <module>
#       register_finder(pkgutil.ImpImporter, find_on_path)
#                       ^^^^^^^^^^^^^^^^^^^
#   AttributeError: module 'pkgutil' has no attribute 'ImpImporter'. Did you mean: 'zipimporter'?
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# Getting requirements to build wheel did not run successfully.
# exit code: 1
#
# See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
from pandas_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# ---------------------------------------------------------------------------
# PydanticImportError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from pandas_profiling import ProfileReport
#       2 prof = ProfileReport(df)
#       3 prof.to_file(output_file='output.html')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas_profiling\__init__.py:8
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
#       6 from warnings import warn
# ----> 8 from pandas_profiling.compare_reports import compare
#       9 from pandas_profiling.controller import pandas_decorator
#      10 from pandas_profiling.profile_report import ProfileReport
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas_profiling\compare_reports.py:6
#       2 from typing import Any, List, Optional, Tuple, Union
#       4 import pandas as pd
# ----> 6 from pandas_profiling.config import Correlation, Settings
#       7 from pandas_profiling.model.alerts import Alert
#       8 from pandas_profiling.profile_report import ProfileReport
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas_profiling\config.py:7
#       4 from typing import Any, Dict, List, Optional, Tuple, Union
#       6 import yaml
# ----> 7 from pydantic import BaseModel, BaseSettings, Field, PrivateAttr
#      10 def _merge_dictionaries(dict1: dict, dict2: dict) -> dict:
#      11     """
#      12     Recursive merge dictionaries.
#      13
#    (...)
#      16     :return: Merged dictionary
#      17     """
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pydantic\__init__.py:218, in __getattr__(attr_name)
#     216 dynamic_attr = _dynamic_imports.get(attr_name)
#     217 if dynamic_attr is None:
# --> 218     return _getattr_migration(attr_name)
#     220 package, module_name = dynamic_attr
#     222 from importlib import import_module
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pydantic\_migration.py:294, in getattr_migration.<locals>.wrapper(name)
#     292     return import_string(REDIRECT_TO_V1[import_path])
#     293 if import_path == 'pydantic:BaseSettings':
# --> 294     raise PydanticImportError(
#     295         '`BaseSettings` has been moved to the `pydantic-settings` package. '
#     296         f'See https://docs.pydantic.dev/{version_short()}/migration/#basesettings-has-moved-to-pydantic-settings '
#     297         'for more details.'
#     298     )
#     299 if import_path in REMOVED_IN_V2:
#     300     raise PydanticImportError(f'`{import_path}` has been removed in V2.')
#
# PydanticImportError: `BaseSettings` has been moved to the `pydantic-settings` package. See https://docs.pydantic.dev/2.4/migration/#basesettings-has-moved-to-pydantic-settings for more details.
#
# For further information visit https://errors.pydantic.dev/2.4/u/import-error
